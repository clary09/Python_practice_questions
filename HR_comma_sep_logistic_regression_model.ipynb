# %% [markdown]
# <h3><strong>Importing required packages</strong></h3>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# <h3><strong>Reading data from data set</strong></h3>

# %%
df=pd.read_csv('HR_comma_sep.csv')
df
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 0                    0.38             0.53               2
# 1                    0.80             0.86               5
# 2                    0.11             0.88               7
# 3                    0.72             0.87               5
# 4                    0.37             0.52               2
# ...                   ...              ...             ...
# 14994                0.40             0.57               2
# 14995                0.37             0.48               2
# 14996                0.37             0.53               2
# 14997                0.11             0.96               6
# 14998                0.37             0.52               2
#
#        average_montly_hours  time_spend_company  Work_accident  left  \
# 0                       157                   3              0     1
# 1                       262                   6              0     1
# ...

# %%
df.head()
# Out:
#    satisfaction_level  last_evaluation  number_project  average_montly_hours  \
# 0                0.38             0.53               2                   157
# 1                0.80             0.86               5                   262
# 2                0.11             0.88               7                   272
# 3                0.72             0.87               5                   223
# 4                0.37             0.52               2                   159
#
#    time_spend_company  Work_accident  left  promotion_last_5years Department  \
# 0                   3              0     1                      0      sales
# 1                   6              0     1                      0      sales
# 2                   4              0     1                      0      sales
# 3                   5              0     1                      0      sales
# 4                   3              0     1                      0      sales
#
#    salary
# 0     low
# 1  medium
# ...

# %% [markdown]
# <h4><strong>Exploratory data analysis</strong></h4>

# %%
df.describe()
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# count        14999.000000     14999.000000    14999.000000
# mean             0.612834         0.716102        3.803054
# std              0.248631         0.171169        1.232592
# min              0.090000         0.360000        2.000000
# 25%              0.440000         0.560000        3.000000
# 50%              0.640000         0.720000        4.000000
# 75%              0.820000         0.870000        5.000000
# max              1.000000         1.000000        7.000000
#
#        average_montly_hours  time_spend_company  Work_accident          left  \
# count          14999.000000        14999.000000   14999.000000  14999.000000
# mean             201.050337            3.498233       0.144610      0.238083
# std               49.943099            1.460136       0.351719      0.425924
# min               96.000000            2.000000       0.000000      0.000000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14999 entries, 0 to 14998
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   satisfaction_level     14999 non-null  float64
#  1   last_evaluation        14999 non-null  float64
#  2   number_project         14999 non-null  int64
#  3   average_montly_hours   14999 non-null  int64
#  4   time_spend_company     14999 non-null  int64
#  5   Work_accident          14999 non-null  int64
#  6   left                   14999 non-null  int64
#  7   promotion_last_5years  14999 non-null  int64
#  8   Department             14999 non-null  object
#  9   salary                 14999 non-null  object
# dtypes: float64(2), int64(6), object(2)
# memory usage: 1.1+ MB

# %%
df.shape
# Out:
# (14999, 10)

# %%
#checking if there are any empty rows or empty columns
df.isnull().sum()
# Out:
# satisfaction_level       0
# last_evaluation          0
# number_project           0
# average_montly_hours     0
# time_spend_company       0
# Work_accident            0
# left                     0
# promotion_last_5years    0
# Department               0
# salary                   0
# dtype: int64

# %%
#to calculate the number of persons who left 
no_of_people_left=df[df.left==1]
no_of_people_left.shape
# Out:
# (3571, 10)

# %%
#to calculate the number of people who retained
no_of_people_retained=df[df.left==0]
no_of_people_retained.shape
# Out:
# (11428, 10)

# %%
#to ananlyse the criterias which have direct and clear effect on employee retention
df.groupby('left').mean()
# Out:
#       satisfaction_level  last_evaluation  number_project  \
# left
# 0               0.666810         0.715473        3.786664
# 1               0.440098         0.718113        3.855503
#
#       average_montly_hours  time_spend_company  Work_accident  \
# left
# 0               199.060203            3.380032       0.175009
# 1               207.419210            3.876505       0.047326
#
#       promotion_last_5years
# left
# 0                  0.026251
# 1                  0.005321

# %% [markdown]
# <h3><strong>On analysing we found that particularly:
#     <br>1. 'satisfaction_level' <br> 2. 'average_monthly_hours'<br> 3. 'promotion_last_5years'<br> had a strong impact on employee retention</strong></h3>

# %% [markdown]
# <h3><strong>Below is a bar graph :'salary' vs 'left'</strong></h3>

# %%
pd.crosstab(df.salary,df.left).plot(kind='bar',color={0:'red',1:'yellow'},width=0.6)
# Out:
# <AxesSubplot:xlabel='salary'>

# %% [markdown]
# <h3><strong>Below is a bar graph :'Department' vs 'left'</strong></h3>

# %%
pd.crosstab(df.Department,df.left).plot(kind='bar',color={0:'red',1:'yellow'},width=0.7)
# Out:
# <AxesSubplot:xlabel='Department'>

# %%
y=df['left']
y
# Out:
# 0        1
# 1        1
# 2        1
# 3        1
# 4        1
#         ..
# 14994    1
# 14995    1
# 14996    1
# 14997    1
# 14998    1
# Name: left, Length: 14999, dtype: int64

# %%
col=df[['satisfaction_level','average_montly_hours','promotion_last_5years','salary']]
col
# Out:
#        satisfaction_level  average_montly_hours  promotion_last_5years  salary
# 0                    0.38                   157                      0     low
# 1                    0.80                   262                      0  medium
# 2                    0.11                   272                      0  medium
# 3                    0.72                   223                      0     low
# 4                    0.37                   159                      0     low
# ...                   ...                   ...                    ...     ...
# 14994                0.40                   151                      0     low
# 14995                0.37                   160                      0     low
# 14996                0.37                   143                      0     low
# 14997                0.11                   280                      0     low
# 14998                0.37                   158                      0     low
#
# ...

# %%
dummies = pd.get_dummies(col.salary, prefix="salary")
df_final = pd.concat([col,dummies],axis='columns')
df_final.drop('salary',axis='columns',inplace=True)
df_final
# Out:
#        satisfaction_level  average_montly_hours  promotion_last_5years  \
# 0                    0.38                   157                      0
# 1                    0.80                   262                      0
# 2                    0.11                   272                      0
# 3                    0.72                   223                      0
# 4                    0.37                   159                      0
# ...                   ...                   ...                    ...
# 14994                0.40                   151                      0
# 14995                0.37                   160                      0
# 14996                0.37                   143                      0
# 14997                0.11                   280                      0
# 14998                0.37                   158                      0
#
#        salary_high  salary_low  salary_medium
# 0                0           1              0
# ...

# %%
x=df_final
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,train_size=0.5,random_state=50)

# %%
x_train
# Out:
#        satisfaction_level  average_montly_hours  promotion_last_5years  \
# 1892                 0.44                   141                      0
# 6540                 0.95                   235                      0
# 14250                0.41                   152                      0
# 3778                 0.80                   175                      0
# 1223                 0.75                   228                      0
# ...                   ...                   ...                    ...
# 10206                0.64                   143                      0
# 6253                 0.51                   168                      0
# 10123                0.81                   222                      0
# 5600                 0.22                   255                      0
# 14000                0.72                   239                      0
#
#        salary_high  salary_low  salary_medium
# 1892             0           1              0
# ...

# %%
x_test
# Out:
#        satisfaction_level  average_montly_hours  promotion_last_5years  \
# 5532                 0.58                   157                      1
# 3341                 0.64                   218                      0
# 8587                 0.94                   203                      0
# 3357                 0.71                   180                      0
# 3573                 0.76                   266                      0
# ...                   ...                   ...                    ...
# 13652                0.61                   134                      0
# 11865                0.74                   224                      0
# 11173                0.95                   199                      0
# 8193                 0.17                   245                      0
# 5512                 0.72                   135                      0
#
#        salary_high  salary_low  salary_medium
# 5532             0           1              0
# ...

# %%
y_train
# Out:
# 1892     1
# 6540     0
# 14250    1
# 3778     0
# 1223     1
#         ..
# 10206    0
# 6253     0
# 10123    0
# 5600     0
# 14000    0
# Name: left, Length: 7499, dtype: int64

# %%
y_test
# Out:
# 5532     0
# 3341     0
# 8587     0
# 3357     0
# 3573     0
#         ..
# 13652    0
# 11865    0
# 11173    0
# 8193     0
# 5512     0
# Name: left, Length: 7500, dtype: int64

# %% [markdown]
# <h3><strong>Model formation:</strong></h3>

# %%
from sklearn.linear_model import LogisticRegression
md = LogisticRegression()
md
# Out:
# LogisticRegression()

# %%
md.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %% [markdown]
# <h3><strong>Accuracy:</strong></h3>

# %%
md.score(x_test,y_test)
# Out:
# 0.7778666666666667
